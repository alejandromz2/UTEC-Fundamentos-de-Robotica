# %%
import numpy as np
import sympy as sp
from sympy import init_printing
from sympy import Matrix
from sympy.interactive import printing
printing.init_printing(use_latex=True)
sin=sp.sin
cos=sp.cos
pi=sp.pi

# %%
#Funciones de rotación canonicas con valores simbolicos
def srotx(ang):
    Rx=sp.Matrix([[1,0,0],
                  [0,sp.cos(ang),-sp.sin(ang)],
                  [0, sp.sin(ang), sp.cos(ang)]])
    return Rx
def sroty(ang):
    Ry= sp.Matrix([[sp.cos(ang),0,sp.sin(ang)],
                  [0,1,0],
                  [-sp.sin(ang), 0, sp.cos(ang)]])
    return Ry
def srotz(ang):
    Rz= sp.Matrix([[sp.cos(ang),-sp.sin(ang),0],
                  [sp.sin(ang), sp.cos(ang), 0],
                  [0,0,1]])
    return Rz


#T given t,R
def T_tR(t,R):
    T = np.vstack((np.hstack((R,t)),np.array([[0, 0, 0, 1]])))
    return T
def rotdh(d,th,a,alf):
    T=sp.Matrix([[cos(th),-cos(alf)*sin(th),sin(alf)*sin(th),a*cos(th)],
                  [sin(th),cos(alf)*cos(th),-sin(alf)*cos(th),a*sin(th)],
                  [0, sin(alf), cos(alf),d],[0, 0, 0, 1]])
    return T

# %%
#Cinematica directa
q1,q2,q3,q4,q5,q6,l1,l2,l3,l4,l5= sp.symbols('q1 q2 q3 q4 q5 q6 l1 l2 l3 l4 l5')

T01=rotdh(l1,pi/2+q1,0,0)
T12=rotdh(l2+q2,0,0,pi/2)
T23=rotdh(0,pi+q3,l3,0)
T34=rotdh(0,0+q4,l4,0)
T45=rotdh(0,0+q5,0,pi/2)
T56=rotdh(-l5,pi+q6,0,0)
T06=sp.simplify(T01*T12*T23*T34*T45*T56)
print('Cinematica directa'), display(T06)

#Hacemos todos los angulos 0
T06i=T06.subs({q1:0,q2:0,q3:0,q4:0,q5:0,q6:0})
print('Cinematica directa cuando qi=0'), display(T06i)
print(T06)
# Out:
# Cinematica directa
# ⎡-sin(q₁)⋅cos(q₆)⋅cos(q₃ + q₄ + q₅) - sin(q₆)⋅cos(q₁)  sin(q₁)⋅sin(q₆)⋅cos(q₃
# ⎢
# ⎢-sin(q₁)⋅sin(q₆) + cos(q₁)⋅cos(q₆)⋅cos(q₃ + q₄ + q₅)  -sin(q₁)⋅cos(q₆) - sin(
# ⎢
# ⎢             sin(q₃ + q₄ + q₅)⋅cos(q₆)                             -sin(q₆)⋅s
# ⎢
# ⎣                         0
#
# + q₄ + q₅) - cos(q₁)⋅cos(q₆)   sin(q₁)⋅sin(q₃ + q₄ + q₅)     (l₃⋅cos(q₃) + l₄⋅
#
# q₆)⋅cos(q₁)⋅cos(q₃ + q₄ + q₅)  -sin(q₃ + q₄ + q₅)⋅cos(q₁)    (-l₃⋅cos(q₃) - l₄
#
# in(q₃ + q₄ + q₅)                   cos(q₃ + q₄ + q₅)       l₁ + l₂ - l₃⋅sin(q₃
#
#   0                                        0
#
# cos(q₃ + q₄) - l₅⋅sin(q₃ + q₄ + q₅))⋅sin(q₁)   ⎤
#                                                ⎥
# ⋅cos(q₃ + q₄) + l₅⋅sin(q₃ + q₄ + q₅))⋅cos(q₁)  ⎥
#                                                ⎥
# ) - l₄⋅sin(q₃ + q₄) - l₅⋅cos(q₃ + q₄ + q₅) + q₂⎥
#                                                ⎥
#              1                                 ⎦
# Cinematica directa cuando qi=0
# ...

# %%
def R_rpy(R,s):


    if R[2,0] == 0:
        if s == '+':
            fi_p = sp.atan2(R[2,0],sp.sqrt(R[2,1]**2+R[2,2]**2))
        elif s == '-':
            fi_p = sp.atan2(R[2,0],-sp.sqrt(R[2,1]**2+R[2,2]**2))
    else: 
        if s == '+':
            fi_p = sp.atan2(-R[2,0],sp.sqrt(R[2,1]**2+R[2,2]**2))
        elif s == '-':
            fi_p = sp.atan2(-R[2,0],-sp.sqrt(R[2,1]**2+R[2,2]**2))

    if cos(fi_p) != 0:
        fi_r = sp.atan2(R[1,0]/cos(fi_p),R[0,0]/cos(fi_p))
        fi_y = sp.atan2(R[2,1]/cos(fi_p),R[2,2]/cos(fi_p))
        return fi_r, fi_p, fi_y

# %%
#Jacobiano Analitico
#Posicion
#Cinematica directa
X=sp.Matrix([[ (l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*sin(q1)],[(-l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5))*cos(q1)],[l1 + l2 - l3*sin(q3) - l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5) + q2]])
# Variables articulares
q = sp.Matrix([q1, q2, q3,q4,q5,q6])
# Jacobiano analítico
Ja = X.jacobian(q)



#Orientacion
R06=sp.simplify(T06[:3,:3])

Rrpy=sp.simplify(R_rpy(R06,'+'))

d1q1=sp.diff(Rrpy[0],q1)
d1q2=sp.diff(Rrpy[0],q2)
d1q3=sp.diff(Rrpy[0],q3)
d1q4=sp.diff(Rrpy[0],q4)
d1q5=sp.diff(Rrpy[0],q5)
d1q6=sp.diff(Rrpy[0],q6)
d2q1=sp.diff(Rrpy[1],q1)
d2q2=sp.diff(Rrpy[1],q2)
d2q3=sp.diff(Rrpy[1],q3)
d2q4=sp.diff(Rrpy[1],q4)
d2q5=sp.diff(Rrpy[1],q5)
d2q6=sp.diff(Rrpy[1],q6)
d3q1=sp.diff(Rrpy[2],q1)
d3q2=sp.diff(Rrpy[2],q2)
d3q3=sp.diff(Rrpy[2],q3)
d3q4=sp.diff(Rrpy[2],q4)
d3q5=sp.diff(Rrpy[2],q5)
d3q6=sp.diff(Rrpy[2],q6)

Ja=sp.Matrix([[(l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*cos(q1),0, (-l3*sin(q3) - l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5))*sin(q1),(-l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5))*sin(q1), -l5*sin(q1)*cos(q3 + q4 + q5), 0],
              [-(-l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5))*sin(q1), 0, (l3*sin(q3) + l4*sin(q3 + q4) + l5*cos(q3 + q4 + q5))*cos(q1), (l4*sin(q3 + q4) + l5*cos(q3 + q4 + q5))*cos(q1), l5*cos(q1)*cos(q3 + q4 + q5), 0],
              [0, 1, -l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5), -l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5), l5*sin(q3 + q4 + q5), 0],
              [d1q1,d1q2,d1q3,d1q4,d1q5,d1q6],
    [d2q1,d2q2,d2q3,d2q4,d2q5,d2q6],
    [d3q1,d3q2,d3q3,d3q4,d3q5,d3q6]])

f=sp.Matrix([[ (l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*sin(q1)],
                   [(-l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5))*cos(q1)],
                   [l1 + l2 - l3*sin(q3) - l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5) + q2],
                   [Rrpy[0]],
                   [Rrpy[1]],
                   [Rrpy[2]]])
Ja
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                       (-sin(q₁)⋅sin(q₆) + co
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢⎛                                                      2
# ⎢⎜(-sin(q₁)⋅sin(q₆) + cos(q₁)⋅cos(q₆)⋅cos(q₃ + q₄ + q₅))    (sin(q₁)⋅cos(q₆)⋅c
# ⎢⎜─────────────────────────────────────────────────────── + ──────────────────
# ⎢⎜       2        2                    2                          2        2
# ⎢⎝    sin (q₆)⋅sin (q₃ + q₄ + q₅) + cos (q₃ + q₄ + q₅)         sin (q₆)⋅sin (q
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                                                            (l₃⋅cos(q₃) + l₄⋅co
#
#                                                            (l₃⋅cos(q₃) + l₄⋅co
#
#
#
#
#
#
#
#                                 2
# s(q₁)⋅cos(q₆)⋅cos(q₃ + q₄ + q₅))
# ...

# %%
#Metodo Gradiente Descendiente
import numpy as np
cos=np.cos; sin=np.sin; sqrt=np.sqrt; atan2=np.arctan2
l1=0.65;
l2=0.65;
l3=0.45;
l4=0.45;
l5=0.3;
twist_deseado = np.array([[1.2],[0],[1], [np.pi/4],[np.pi/4],[np.pi/4]]) # Desired value in the Cartesian space
q = np.array([[0],[0],[0], [0],[0],[0]]) # Initial value in the joint space
epsilon = 1e-3
max_iter = 100 # Maximum number of iterations
alpha=0.21


# Iterations: Gradient descent
for i in range(max_iter):
    q1 = q[0,0]; q2 = q[1,0]; q3 = q[2,0]; q4 = q[3,0]; q5 = q[4,0]; q6 = q[5,0];
    J = np.array([[(l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*cos(q1), 0, (-l3*sin(q3) - l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5))*sin(q1), (-l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5))*sin(q1), -l5*sin(q1)*cos(q3 + q4 + q5), 0],
                  [(l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*sin(q1), 0, (l3*sin(q3) + l4*sin(q3 + q4) + l5*cos(q3 + q4 + q5))*cos(q1), (l4*sin(q3 + q4) + l5*cos(q3 + q4 + q5))*cos(q1), l5*cos(q1)*cos(q3 + q4 + q5), 0], 
                  [0, 1, -l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5), -l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5), l5*sin(q3 + q4 + q5), 0], 
                  [(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)) - (-sin(q1)*cos(q6)*cos(q3 + q4 + q5) - sin(q6)*cos(q1))*(sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)), 0, -(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(sin(q1)*sin(q3 + q4 + q5)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)) - ((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2) - sin(q3 + q4 + q5)*cos(q1)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*(sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)), -(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(sin(q1)*sin(q3 + q4 + q5)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)) - ((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2) - sin(q3 + q4 + q5)*cos(q1)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*(sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)), -(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(sin(q1)*sin(q3 + q4 + q5)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)) - ((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*(-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2) - sin(q3 + q4 + q5)*cos(q1)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*(sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)), -(-(-sin(q1)*sin(q6)*cos(q3 + q4 + q5) + cos(q1)*cos(q6))/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))*sin(q6)*sin(q3 + q4 + q5)**2*cos(q6)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)) - (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))*(-(-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))*sin(q6)*sin(q3 + q4 + q5)**2*cos(q6)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2) + (-sin(q1)*cos(q6) - sin(q6)*cos(q1)*cos(q3 + q4 + q5))/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))/(((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))*sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))], 
                  [0, 0, -sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*cos(q6)*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2) + (sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) - sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q3 + q4 + q5)*cos(q6)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2)), -sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*cos(q6)*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2) + (sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) - sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q3 + q4 + q5)*cos(q6)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2)), -sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*cos(q6)*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2) + (sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) - sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q3 + q4 + q5)*cos(q6)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2)), sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*sin(q6)*sin(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2) + sin(q6)*sin(q3 + q4 + q5)**3*cos(q6)**2/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2 + sin(q3 + q4 + q5)**2*cos(q6)**2 + cos(q3 + q4 + q5)**2))], 
                  [0, 0, (-sin(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*sin(q6)*sin(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))) + (-sin(q6)*cos(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q6)*sin(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*cos(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))), (-sin(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*sin(q6)*sin(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))) + (-sin(q6)*cos(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q6)*sin(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*cos(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))), (-sin(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*cos(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*sin(q6)*sin(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))) + (-sin(q6)*cos(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) - (-sin(q6)**2*sin(q3 + q4 + q5)*cos(q3 + q4 + q5) + sin(q3 + q4 + q5)*cos(q3 + q4 + q5))*sin(q6)*sin(q3 + q4 + q5)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*cos(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))), -sin(q6)**2*sin(q3 + q4 + q5)**3*cos(q6)*cos(q3 + q4 + q5)/((sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**2*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))) + (-sin(q3 + q4 + q5)*cos(q6)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + sin(q6)**2*sin(q3 + q4 + q5)**3*cos(q6)/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)**(3/2))*cos(q3 + q4 + q5)/(sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)*(sin(q6)**2*sin(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2) + cos(q3 + q4 + q5)**2/(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2)))]])
    
    f=np.array([[(l3*cos(q3) + l4*cos(q3 + q4) - l5*sin(q3 + q4 + q5))*sin(q1)],
                [(-l3*cos(q3) - l4*cos(q3 + q4) + l5*sin(q3 + q4 + q5))*cos(q1)],
                [l1 + l2 - l3*sin(q3) - l4*sin(q3 + q4) - l5*cos(q3 + q4 + q5) + q2],
                [atan2((-sin(q1)*sin(q6) + cos(q1)*cos(q6)*cos(q3 + q4 + q5))/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2), -(sin(q1)*cos(q6)*cos(q3 + q4 + q5) + sin(q6)*cos(q1))/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))],
                [np.arctan2(-sin(q3 + q4 + q5)*cos(q6), sqrt(np.sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))],
                [atan2(-sin(q6)*sin(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2), cos(q3 + q4 + q5)/sqrt(sin(q6)**2*sin(q3 + q4 + q5)**2 + cos(q3 + q4 + q5)**2))]])
     
        
    e = twist_deseado-f
    q = q + alpha*np.dot(J.T, e)

    if (np.linalg.norm(e) < epsilon):
        break
    if (i==max_iter-1):
        print("El algoritmo diverge, escoger un alpha más pequeño")

        
print(q)
# Out:
# El algoritmo diverge, escoger un alpha más pequeño
# [[ 1.51749925]
#  [-0.10699583]
#  [-0.01820543]
#  [ 0.07776153]
#  [ 0.90514196]
#  [-2.53773671]]

# %%
np.linalg.norm(e)
# Out:
# 0.5615312692800765

# %%
np.round(f,3)
# Out:
# array([[ 0.925],
#        [-0.   ],
#        [ 1.001],
#        [ 0.   ],
#        [-0.083],
#        [-0.   ]])

# %%
# Out:
# array([[ 2.65105295e+00],
#        [ 2.41896806e+00],
#        [ 1.06012628e+00],
#        [-1.22124533e-14],
#        [-1.19502400e-14],
#        [ 7.69026364e-15]])
